# %% [markdown]
# # TP N°2: Alineamiento de secuencias y BLAST
# **Bioinformática 2026**

# %% [markdown]
# ---
# ## Objetivo 1: Uso de BLAST en NCBI-web
# ### Objetivo 1.1 — Comparación de 2 secuencias
#
# **Preguntas generales sobre la interfaz:**
#
# - ¿Qué opciones de programas hay y para qué tipo de comparaciones sirven?
# - ¿Qué otras matrices hay disponibles? ¿Conoce sus diferencias?
# - ¿Qué particularidad tienen los valores de gap costs (existence y extension)? ¿A qué se debe?

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# ---
# ### Ejercicio 1.1
#
# Comparación de mioglobina humana con 2-3 mioglobinas de otros organismos.
#
# **i) ¿El alineamiento abarca la secuencia completa de las 2 proteínas? ¿Es local o global? Justifique.**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **ii) ¿Se observan gaps en el dot-plot? ¿Cuántos? ¿Cómo se identifican?**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **iii) Analice el resultado tomando en cuenta Score, E-value, Identities, Positives y Gaps.**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **Variación de parámetros:**
#
# - a) Matriz BLOSUM-80
# - b) Gap existence/extension: 11:2
# - c) Gap existence/extension: 9:1
#
# ¿Qué cambios se observan en cada caso? Interprete en base a las diferencias entre matrices de sustitución.

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# ---
# ## Objetivo 1.2 — Búsqueda de proteínas homólogas a la mioglobina humana
#
# ### Ejercicio 1.2
#
# **i) ¿Cómo mejoraría la búsqueda para obtener solo proteínas homólogas a la Mb una sola vez?**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **ii) Describa brevemente cada proteína homóloga encontrada. Compare E-values, scores y alineamientos.**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **iii) ¿Cuál es la globina humana más parecida a la Mioglobina? ¿Le sorprende algún resultado?**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **iv) ¿Cree que encontró todas las proteínas de la familia de las globinas que existen en el genoma humano?**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **v) Intente encontrar la mayor cantidad de globinas modificando parámetros de BLASTp. ¿Qué parámetros modificó y qué nuevas proteínas encontró?**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# **vi) PSI-BLAST: ¿Encontraron alguna proteína que no había aparecido antes? ¿Cuántas iteraciones realizaron?**

# %% [markdown]
# *Respuesta:*

# %% [markdown]
# ---
# ## Objetivo 2: Uso de BLAST en línea de comando
#
# Los ejercicios de esta sección se desarrollan en los scripts de la carpeta `scripts/`.
#
# Los comandos de descarga y preparación de datos están documentados en cada script.

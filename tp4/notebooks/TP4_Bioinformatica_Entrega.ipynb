# %% [markdown]
# # TP N°4 Minería de Datos y Modelos Ocultos de Markov
# **Bioinformática 2026**

# %%
from Bio import AlignIO

alineamiento = AlignIO.read("../PF11563.alignment.seed", "stockholm")
AlignIO.write(alineamiento, "../resultados/PF11563.fasta", "fasta")
# Out:
# 1

# %% [markdown]
# ### 1c) Realizar el MSA con MAFFT.

# %%
# !mafft /Users/alexmary/Documents/bioinformatica/intro_a_bioinfo/tp4/resultados/PF11563.fasta > /Users/alexmary/Documents/bioinformatica/intro_a_bioinfo/tp4/resultados/PF11563_msa.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8176 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#     1 / 62
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#    60 / 62
# done.
#
# Progressive alignment 1/2...
# STEP    61 / 61
# done.
#
# Making a distance matrix from msa..
#     0 / 62
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#    60 / 62
# done.
#
# Progressive alignment 2/2...
# STEP    61 / 61
# done.
#
# disttbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# ...
